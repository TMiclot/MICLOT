# %%
pwd
# Out:
# '/home/miclot/GitHub/MICLOT/MICLOT'

# %%
ls
# Out:
# __banner.png  miclot/    test.ipynb     Tutorial/
# LICENSE       README.md  to_do_list.md  User_Guide/

# %%
import miclot.database as db

# %%
db.amino_acids
# Out:
#        amino_acid code_1letter code_standard  code_reduced code_oxydized  \
# 0         alanine            A            ALA         None          None
# 1        arginine            R            ARG         None          None
# 2      asparagine            N            ASN         None          None
# 3       aspartate            D            ASP          ASH          None
# 4        cysteine            C            CYS          CYH           CYX
# 5       glutamine            Q            GLN         None          None
# 6       glutamate            E            GLU          GLH          None
# 7         glycine            G            GLY         None          None
# 8       histidine            H            HIS         None          None
# 9      isoleucine            I            ILE         None          None
# 10        leucine            L            LEU         None          None
# 11         lysine            K            LYS         None          None
# ...

# %%
db.elements
# Out:
#     element symbol  atomic_weight  van_der_waals_radii  covalent_radii spin  \
# 0    carbon      C         12.011                 1.70            0.75    0
# 1  hydrogen      H          1.008                 1.10            0.32  1/2
# 2  nitrogen      N         14.007                 1.55            0.71    1
# 3    oxygen      O         15.999                 1.52            0.64    0
# 4  selenium     Se         78.971                 1.90            1.18    0
# 5   sulfure      S         32.076                 1.80            1.04    0
#
#   mag_moment  I_Ground_state_ionization_energy  \
# 0       None                         11.260300
# 1    2.79284                         13.598433
# 2    0.40376                         14.534100
# 3       None                         13.618050
# 4       None                          9.752390
# 5       None                         10.360010
#
#   II_Ground_state_ionization_energy
# 0                           24.3833
# ...

# %%
import miclot.utilities as mcu

# %%
help(mcu.minimize_pdb)
# Out:
# Help on function minimize_pdb in module miclot.utilities:
#
# minimize_pdb(pdb_file_path, force_field='amber', max_iterations=100, restrain_heavy_atoms=True, constant=100000.0)
#     DESCRIPTION
#         This command is a parser to minimize a structure using openMM.
#         It generate a PDB file and an output file in CSV format containing
#         the energy of the structure at each step of the minimization.
#
#
#     ARGUMENTS
#         pdb_file_path    Path of the pDB file.
#
#
#     OPTIONAL ARGUMENTS
#         force_field      Force field 'amber' or 'charmm'.
#                          Default value: 'amber'
#
#         max_iterations   Maximum number of iteration. Too hight number can lead to structure deformation.
#                          Default value: 100
#
#         restrain_heavy_atoms    Apply restain force to heavy atom to avoid them moving too far from their
# ...

# %%
import miclot.interactions as mci
import miclot as m

# %%
help(m.coulomb_lj.coulomb_lj)
# Out:
# Help on class coulomb_lj in module miclot.coulomb_lj:
#
# class coulomb_lj(builtins.object)
#  |  coulomb_lj(trajectory, res_index_A, res_index_B, force_field_path, frame=0, coulomb_cutoff=12, lj_cutoff=12, lj_switch=8, solute_dielectric=1.0, solvent_dielectric=78.5)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, trajectory, res_index_A, res_index_B, force_field_path, frame=0, coulomb_cutoff=12, lj_cutoff=12, lj_switch=8, solute_dielectric=1.0, solvent_dielectric=78.5)
#  |      ENERGY TYPE    Coulomb & Lennar-Jones
#  |      SUBTYPE(S)     Coulomb, Lennar-Jones
#  |
#  |      DESCRIPTION
#  |          Coulomb & Lennar-Jones interaction between residues.
#  |
#  |      ARGUMENTS
#  |          trajectory     MDTraj trajectory
#  |          res_index_A    Index of residue A
#  |          res_index_B    Index of residue B
#  |
#  |      OPTIONAL ARGUMENTS
#  |          frame                 Frame ID on which to perform the analysis.
# ...
